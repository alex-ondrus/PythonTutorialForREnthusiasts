# %% [markdown]
# # Solutions to Bayesian Inference with PyMC
#
# ## Simple Linear Regression

# %%
import pymc as pm
import numpy as np
# Out:
# ---------------------------------------------------------------------------
#
# ModuleNotFoundError                       Traceback (most recent call last)
#
# Cell In[1], line 1
#
# ----> 1 import pymc as pm
#
#       2 import numpy as np
#
#
#
# ModuleNotFoundError: No module named 'pymc'
